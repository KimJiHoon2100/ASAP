# %% [markdown]
# # Mouse disease phase detection program using CNN with Keras api

# %% [markdown]
# ## Training Phase

# %% [markdown]
# (1) 사용할 패키지 불러오기

# %%
import numpy as np
import keras
# %matplotlib inline
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Activation
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils.vis_utils import plot_model
from keras.models import load_model
from keras.utils import np_utils
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# (2) 데이터 셋 불러오기 & 생성하기

# %%
#np.random.seed(3)

#train_datagen = ImageDataGenerator(rescale = 1./255)

#train_generator = train_datagen.flow_from_directory('OpenFieldTest/Origin/Training',
#                                                    target_size = (40,40), #픽셀 사이즈 선정 필요
#                                                    batch_size = 3,
#                                                    class_mode = 'categorical')

#test_datagen = ImageDataGenerator(rescale = 1./255)

#test_generator = test_datagen.flow_from_directory('OpenFieldTest/Origin/Test',
#                                                  target_size = (40,40), #픽셀 사이즈 선정 필요
#                                                  batch_size = 3,
#                                                  class_mode = 'categorical')

# %% [markdown]
# (cf) 예측할 데이터 샘플 보이기

# %%
# 해결법1
from skimage import io

image = io.imread('Training/WT/WT_1-0_Set2_Head_ctrl401.png')

print(type(image))
plt.imshow(image);

ic = io.imread_collection('training/wt/*.png')

print(type(ic), '\n\n', ic)

f, axes = plt.subplots(nrows=1, ncols=len(ic), figsize=(20,20))

for i, image in enumerate(ic):
    axes[i].imshow(image, cmap='gray')
    axes[i].axis('off')
    
ec = io.imread_collection('training/tg/*.png')

print(type(ec), '\n\n', ic)

f, axes = plt.subplots(nrows=1, ncols=len(ec), figsize=(20,20))

for i, image in enumerate(ec):
    axes[i].imshow(image, cmap='gray')
    axes[i].axis('off')
# Out:
# <class 'numpy.ndarray'>
# <class 'skimage.io.collection.ImageCollection'>
#
#  ['training/wt\\WT_1-0_Set2_Head_ctrl401.png', 'training/wt\\WT_1-1_Set4_Center_ctrl401.png', 'training/wt\\WT_1-2_Set2_Center_ctrl402.png', 'training/wt\\WT_1-2_Set2_Head_ctrl402.png', 'training/wt\\WT_1-3_Set2_Head_ctrl403.png', 'training/wt\\WT_1-8_Set2_Center_ctrl404.png', 'training/wt\\WT_1-8_Set2_Head_ctrl404.png', 'training/wt\\WT_3-2_Set1_Head_ctrl401.png', 'training/wt\\WT_3-3_Set1_Center_ctrl402.png', 'training/wt\\WT_3-3_Set1_Head_ctrl402.png', 'training/wt\\WT_3-5_Set1_Head_ctrl403.png', 'training/wt\\WT_3-8_Set1_Center_ctrl401.png', 'training/wt\\WT_3-8_Set1_Head_ctrl401.png', 'training/wt\\WT_5-0_Set1_Center_ctrl402.png', 'training/wt\\WT_5-1_Set1_Center_ctrl403.png', 'training/wt\\WT_5-4_Set4_Center_ctrl401.png', 'training/wt\\WT_5-4_Set4_Head_ctrl401.png', 'training/wt\\WT_5-8_Set1_Center_ctrl404.png', 'training/wt\\WT_5-9_Set2_Center_ctrl401.png', 'training/wt\\WT_5-9_Set2_Head_ctrl401.png', 'training/wt\\WT_7-0_Set2_Head_ctrl402.png', 'training/wt\\WT_7-1_Set4_Center_ctrl402.png', 'training/wt\\WT_8-2-3_Set1_center_ctrl401.png', 'training/wt\\WT_8-2-3_Set1_head_ctrl401.png', 'training/wt\\WT_8-3-1_Set1_head_ctrl402.png', 'training/wt\\WT_8-3-3_Set1_center_ctrl403.png', 'training/wt\\WT_8-3-3_Set1_head_ctrl403.png', 'training/wt\\WT_8-5-2_Set1_head_ctrl404.png', 'training/wt\\WT_8-6-4_Set2_center_ctrl401.png', 'training/wt\\WT_8-7-4_Set2_center_ctrl402.png', 'training/wt\\WT_8-7-4_Set2_head_ctrl402.png', 'training/wt\\WT_8-8-1_Set2_head_ctrl403.png', 'training/wt\\WT_8-8-3_Set2_center_ctrl404.png', 'training/wt\\WT_8-9-3_Set8_center_ctrl401.png', 'training/wt\\WT_8-9-3_Set8_head_ctrl401.png', 'training/wt\\WT_8-9-6_Set8_center_ctrl402.png']
# <class 'skimage.io.collection.ImageCollection'>
#
#  ['training/wt\\WT_1-0_Set2_Head_ctrl401.png', 'training/wt\\WT_1-1_Set4_Center_ctrl401.png', 'training/wt\\WT_1-2_Set2_Center_ctrl402.png', 'training/wt\\WT_1-2_Set2_Head_ctrl402.png', 'training/wt\\WT_1-3_Set2_Head_ctrl403.png', 'training/wt\\WT_1-8_Set2_Center_ctrl404.png', 'training/wt\\WT_1-8_Set2_Head_ctrl404.png', 'training/wt\\WT_3-2_Set1_Head_ctrl401.png', 'training/wt\\WT_3-3_Set1_Center_ctrl402.png', 'training/wt\\WT_3-3_Set1_Head_ctrl402.png', 'training/wt\\WT_3-5_Set1_Head_ctrl403.png', 'training/wt\\WT_3-8_Set1_Center_ctrl401.png', 'training/wt\\WT_3-8_Set1_Head_ctrl401.png', 'training/wt\\WT_5-0_Set1_Center_ctrl402.png', 'training/wt\\WT_5-1_Set1_Center_ctrl403.png', 'training/wt\\WT_5-4_Set4_Center_ctrl401.png', 'training/wt\\WT_5-4_Set4_Head_ctrl401.png', 'training/wt\\WT_5-8_Set1_Center_ctrl404.png', 'training/wt\\WT_5-9_Set2_Center_ctrl401.png', 'training/wt\\WT_5-9_Set2_Head_ctrl401.png', 'training/wt\\WT_7-0_Set2_Head_ctrl402.png', 'training/wt\\WT_7-1_Set4_Center_ctrl402.png', 'training/wt\\WT_8-2-3_Set1_center_ctrl401.png', 'training/wt\\WT_8-2-3_Set1_head_ctrl401.png', 'training/wt\\WT_8-3-1_Set1_head_ctrl402.png', 'training/wt\\WT_8-3-3_Set1_center_ctrl403.png', 'training/wt\\WT_8-3-3_Set1_head_ctrl403.png', 'training/wt\\WT_8-5-2_Set1_head_ctrl404.png', 'training/wt\\WT_8-6-4_Set2_center_ctrl401.png', 'training/wt\\WT_8-7-4_Set2_center_ctrl402.png', 'training/wt\\WT_8-7-4_Set2_head_ctrl402.png', 'training/wt\\WT_8-8-1_Set2_head_ctrl403.png', 'training/wt\\WT_8-8-3_Set2_center_ctrl404.png', 'training/wt\\WT_8-9-3_Set8_center_ctrl401.png', 'training/wt\\WT_8-9-3_Set8_head_ctrl401.png', 'training/wt\\WT_8-9-6_Set8_center_ctrl402.png']

# %%
#해결법2
#import os
#import matplotlib.pyplot as plt
#import PIL
#%matplotlib inline

#rows = 2
#os.chdir('training/wt/')
#files = os.listdir('training/wt/')

#for num, x in enumerate(files):
#    img = PIL,Image.open(x)
#    plt,subplot(rows,6,num+1)
#    plt.title(x.split('.')[0])
#    plt.axis('off')
#    plt.imshow(img)

# %%
#해결법3
# read image
import matplotlib.image as mpimg
img1 = mpimg.imread('training/wt/WT_1-0_Set2_Head_ctrl401.png')
img2 = mpimg.imread('training/wt/WT_1-1_Set4_Center_ctrl401.png')
# plot image
plt.figure(1)

plt.subplot(1,2,1)
plt.imshow(img1)

plt.subplot(122)
plt.imshow(img2)
plt.show()

# %%
#해결법4
import os
directory=os.listdir('training/')
for each in directory:
    plt.figure()
    currentFolder = 'training/' + each
    for i, file in enumerate(os.listdir(currentFolder)[0:6]):
        fullpath = currentFolder+ "/" + file
        img=mpimg.imread(fullpath)
        print(fullpath)
        plt.subplots_adjust(wspace = 0.5)
        plt.subplot(2,3,i+1)
        plt.imshow(img)
        #plt.ylabel(file)
        #plt.xlabel(file)
        plt.title(each)
# Out:
# training/AV/AV_8-3-2_Set7_center_ctrl403.png
# training/AV/AV_8-3-2_Set7_head_ctrl403.png
# training/AV/AV_8-4-2_Set7_center_ctrl404.png
# training/AV/AV_8-4-2_Set7_head_ctrl404.png
# training/AV/AV_8-4-4_Set5_center_ctrl403.png
# training/AV/AV_8-4-4_Set5_head_ctrl403.png
# training/TG/TG_1-4_Set4_Head_ctrl402.png
# training/TG/TG_3-7_Set3_Center_ctrl402.png
# training/TG/TG_3-7_Set3_Head_ctrl402.png
# training/TG/TG_3-9_Set2_Center_ctrl403.png
# training/TG/TG_5-2_Set2_Center_ctrl404.png
# training/TG/TG_5-2_Set2_Head_ctrl404.png
# training/WT/WT_1-0_Set2_Head_ctrl401.png
# training/WT/WT_1-1_Set4_Center_ctrl401.png
# training/WT/WT_1-2_Set2_Center_ctrl402.png
# training/WT/WT_1-2_Set2_Head_ctrl402.png
# training/WT/WT_1-3_Set2_Head_ctrl403.png
# training/WT/WT_1-8_Set2_Center_ctrl404.png

# %%
#해결법5
#def plot_images():
#    folder = 'training/wt/'
#    images = os.listdir(folder)
#    print(images)
#    i = 0
#    for image in mages:
#        plt.subplot(2,5,i+1)
#        im = imread(folder+image)
#        i+=1
#        imgplot = plt.imshow(im)
#    plt.show()
#    return

#plt.figure(figsize=[40,40])
#plt.subplots_adjust(wspace = 0.5)

# %%
#해결법6
#from io import BytesIO
#import PIL
#form IPython.display import display, Image

#def display_img_array(ima):
#    im = PIL.Image.fromarray(ima)
#    bio = ByteIO()
#    im.save(bio, format='png')
#    display(Image(bio.getvalue(), format='png'))

#for ima in images:
#    display_img_array(ima)

# %%
#import matplotlib.image as mpimg
#img=mpimg.imread('OpenFieldTest/Origin/Training/WT/WT_1-0_Set2_Head_ctrl401.png')#데이터 입력
#img.shape
#imgplot = plt.imshow(img)

# for i in range(plt_row*plt_col):
#    sub_plt = axarr[i/plt_row, i%plt_col]
#    sub_plt.axis('off')
#    sub_plt.imshow(x_test[i].reshape(width, height))
    
#    sub_plt_title = 'R: '
    
#    if y_test[i] :
#        sub_plt_title += 'odd '
#    else:
#        sub_plt_title += 'even '
    
#    sub_plt.set_title(sub_plt_title)

# plt.show()
#plt_row = 3
#plt_col = 3

#plt.rcParams["figure.figsize"] = (10,10)

#f, axarr = plt.subplots(plt_row, plt_col)

#for i in range(plt_row*plt_col):
#    sub_plt = axarr[int(i/plt_row), int(i%plt_col)]
#    sub_plt.axis('off')
#    sub_plt.imshow(train_generator[i])

#plt.show()



# Multinary Sample Visualization
# %matplotlib inline
# import matplotlib.pyplot as plt

# plt_row = 5
# plt_col = 5

# plt.rcParams["figure.figsize"] = (10,10)

# f, axarr = plt.subplots(plt_row, plt_col)

# for i in range(plt_row*plt_col):

#    sub_plt = axarr[i/plt_row, i%plt_col]
#    sub_plt.axis('off')
#    sub_plt.imshow(x_test[i].reshape(width, height))
#    sub_plt_title = 'R: ' + str(np.argmax(y_test[i]))
#    sub_plt.set_title(sub_plt_title)

# plt.show()

# %% [markdown]
# (3) 학습 모델 구성하기

# %%
# Multi2. 모델 구성하기
# model = Sequential()
# model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(width, height, 1)))
# model.add(Conv2D(32, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
# model.add(Conv2D(64, (3, 3), activation='relu'))
# model.add(Conv2D(64, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
# model.add(Flatten())
# model.add(Dense(256, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(10, activation='softmax')) # 다중 분류시

# Binary2. 모델 구성하기
# model = Sequential()
# model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(width, height, 1)))
# model.add(Conv2D(32, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
# model.add(Conv2D(64, (3, 3), activation='relu'))
# model.add(Conv2D(64, (3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
# model.add(Flatten())
# model.add(Dense(256, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(1, activation='sigmoid')) # 2진 분류시

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(40, 40, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(2, activation='softmax'))

# %% [markdown]
# (4) 모델 학습과정 설정하기

# %%
# Multinary 3. 모델 학습과정 설정하기
#model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Binary3. 모델 학습과정 설정하기
#model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %% [markdown]
# (5) 학습 모델 표시하기

# %%
plot_model(model, to_file='model.png', show_shapes =True, show_layer_names = True, rankdir = 'TB')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 38, 38, 32)        896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 19, 19, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 17, 17, 32)        9248
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               262272
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 272,674
# Trainable params: 272,674
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# (6) 모델 학습시키기

# %%
# Multinary,Binary4. 모델 학습시키기
#hist = model.fit(x_train, y_train, epochs=30, batch_size=32, validation_data=(x_val, y_val))

class outputImages(keras.callbacks.Callback):
    def __init__(self, input_data):
        self.input_data = input_data
    
    def on_epoch_end(self, epoch, logs={}):
        if epoch % 10 == 0:
            get_model_layers_output_combined_image(self.model, self.input_data)
            
output_images = outputImages(keras.callbacks.Callback)
history = model.fit_generator(
        train_generator,
        steps_per_epoch=50,
        epochs=100,
        validation_data=test_generator,
        validation_steps=5)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 1s 28ms/step - loss: 0.6824 - acc: 0.5933 - val_loss: 0.6317 - val_acc: 0.7333
# Epoch 2/100
# 50/50 [==============================] - 1s 22ms/step - loss: 0.5438 - acc: 0.7333 - val_loss: 0.6116 - val_acc: 0.6667
# Epoch 3/100
# 50/50 [==============================] - 1s 21ms/step - loss: 0.3662 - acc: 0.8600 - val_loss: 0.5441 - val_acc: 0.6667
# Epoch 4/100
# 50/50 [==============================] - 1s 22ms/step - loss: 0.2586 - acc: 0.9000 - val_loss: 0.4833 - val_acc: 0.7333
# Epoch 5/100
# 50/50 [==============================] - 1s 21ms/step - loss: 0.1798 - acc: 0.9200 - val_loss: 0.4341 - val_acc: 0.7333
# Epoch 6/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0625 - acc: 0.9933 - val_loss: 0.3689 - val_acc: 0.8667
# Epoch 7/100
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0215 - acc: 1.0000 - val_loss: 0.4063 - val_acc: 0.8667
# Epoch 8/100
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0077 - acc: 1.0000 - val_loss: 0.4151 - val_acc: 0.8000
# Epoch 9/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0040 - acc: 1.0000 - val_loss: 0.4440 - val_acc: 0.8000
# Epoch 10/100
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0027 - acc: 1.0000 - val_loss: 0.4487 - val_acc: 0.8000
# Epoch 11/100
# 50/50 [==============================] - 1s 21ms/step - loss: 0.0019 - acc: 1.0000 - val_loss: 0.4654 - val_acc: 0.8000
# Epoch 12/100
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 0.4688 - val_acc: 0.8000
# Epoch 13/100
# 50/50 [==============================] - 1s 21ms/step - loss: 0.0010 - acc: 1.0000 - val_loss: 0.4856 - val_acc: 0.8000
# Epoch 14/100
# 50/50 [==============================] - 1s 20ms/step - loss: 8.2959e-04 - acc: 1.0000 - val_loss: 0.4965 - val_acc: 0.8000
# Epoch 15/100
# 50/50 [==============================] - 1s 22ms/step - loss: 6.7381e-04 - acc: 1.0000 - val_loss: 0.5005 - val_acc: 0.7333
# Epoch 16/100
# 50/50 [==============================] - 1s 21ms/step - loss: 5.4953e-04 - acc: 1.0000 - val_loss: 0.5124 - val_acc: 0.7333
# Epoch 17/100
# 50/50 [==============================] - 1s 22ms/step - loss: 4.6274e-04 - acc: 1.0000 - val_loss: 0.5261 - val_acc: 0.7333
# Epoch 18/100
# 50/50 [==============================] - 1s 22ms/step - loss: 3.0493e-04 - acc: 1.0000 - val_loss: 0.4828 - val_acc: 0.7333
# Epoch 19/100
# 50/50 [==============================] - 1s 21ms/step - loss: 2.4938e-04 - acc: 1.0000 - val_loss: 0.4718 - val_acc: 0.8000
# Epoch 20/100
# 50/50 [==============================] - 1s 21ms/step - loss: 1.5962e-04 - acc: 1.0000 - val_loss: 0.4689 - val_acc: 0.7333
# Epoch 21/100
# 50/50 [==============================] - 1s 22ms/step - loss: 1.0216e-04 - acc: 1.0000 - val_loss: 0.4625 - val_acc: 0.7333
# Epoch 22/100
# 50/50 [==============================] - 1s 20ms/step - loss: 8.5836e-05 - acc: 1.0000 - val_loss: 0.4775 - val_acc: 0.7333
# Epoch 23/100
# 50/50 [==============================] - 1s 22ms/step - loss: 6.0817e-05 - acc: 1.0000 - val_loss: 0.5054 - val_acc: 0.8000
# Epoch 24/100
# 50/50 [==============================] - 1s 24ms/step - loss: 5.2128e-05 - acc: 1.0000 - val_loss: 0.4947 - val_acc: 0.8000
# Epoch 25/100
# 50/50 [==============================] - 1s 21ms/step - loss: 4.4729e-05 - acc: 1.0000 - val_loss: 0.4739 - val_acc: 0.8000
# Epoch 26/100
# 50/50 [==============================] - 1s 23ms/step - loss: 3.2421e-05 - acc: 1.0000 - val_loss: 0.4842 - val_acc: 0.8000
# Epoch 27/100
# 50/50 [==============================] - 1s 21ms/step - loss: 2.9963e-05 - acc: 1.0000 - val_loss: 0.4925 - val_acc: 0.8000
# Epoch 28/100
# 50/50 [==============================] - 1s 22ms/step - loss: 2.5740e-05 - acc: 1.0000 - val_loss: 0.4937 - val_acc: 0.8000
# Epoch 29/100
# 50/50 [==============================] - 1s 22ms/step - loss: 2.1334e-05 - acc: 1.0000 - val_loss: 0.4968 - val_acc: 0.8000
# Epoch 30/100
# 50/50 [==============================] - 1s 23ms/step - loss: 1.8865e-05 - acc: 1.0000 - val_loss: 0.4937 - val_acc: 0.8000
# Epoch 31/100
# 50/50 [==============================] - 1s 23ms/step - loss: 1.6591e-05 - acc: 1.0000 - val_loss: 0.4985 - val_acc: 0.8000
# Epoch 32/100
# 50/50 [==============================] - 1s 21ms/step - loss: 1.4402e-05 - acc: 1.0000 - val_loss: 0.4999 - val_acc: 0.8000
# Epoch 33/100
# 50/50 [==============================] - 1s 22ms/step - loss: 1.3161e-05 - acc: 1.0000 - val_loss: 0.5018 - val_acc: 0.8000
# Epoch 34/100
# 50/50 [==============================] - 1s 22ms/step - loss: 1.2528e-05 - acc: 1.0000 - val_loss: 0.4878 - val_acc: 0.8000
# Epoch 35/100
# 50/50 [==============================] - 1s 22ms/step - loss: 1.0322e-05 - acc: 1.0000 - val_loss: 0.4979 - val_acc: 0.8000
# Epoch 36/100
# 50/50 [==============================] - 1s 21ms/step - loss: 1.0366e-05 - acc: 1.0000 - val_loss: 0.4974 - val_acc: 0.8000
# Epoch 37/100
# 50/50 [==============================] - 1s 22ms/step - loss: 8.6022e-06 - acc: 1.0000 - val_loss: 0.4784 - val_acc: 0.8000
# Epoch 38/100
# 50/50 [==============================] - 1s 21ms/step - loss: 7.9033e-06 - acc: 1.0000 - val_loss: 0.4792 - val_acc: 0.8000
# Epoch 39/100
# 50/50 [==============================] - 1s 22ms/step - loss: 7.4483e-06 - acc: 1.0000 - val_loss: 0.4715 - val_acc: 0.8000
# Epoch 40/100
# 50/50 [==============================] - 1s 24ms/step - loss: 6.9603e-06 - acc: 1.0000 - val_loss: 0.4698 - val_acc: 0.8000
# Epoch 41/100
# 50/50 [==============================] - 1s 20ms/step - loss: 6.0678e-06 - acc: 1.0000 - val_loss: 0.4855 - val_acc: 0.8000
# Epoch 42/100
# 50/50 [==============================] - 1s 22ms/step - loss: 5.8385e-06 - acc: 1.0000 - val_loss: 0.4784 - val_acc: 0.8000
# Epoch 43/100
# 50/50 [==============================] - 1s 22ms/step - loss: 5.5699e-06 - acc: 1.0000 - val_loss: 0.4722 - val_acc: 0.8000
# Epoch 44/100
# 50/50 [==============================] - 1s 22ms/step - loss: 4.4577e-06 - acc: 1.0000 - val_loss: 0.4717 - val_acc: 0.8000
# Epoch 45/100
# 50/50 [==============================] - 1s 21ms/step - loss: 4.5717e-06 - acc: 1.0000 - val_loss: 0.4660 - val_acc: 0.8000
# Epoch 46/100
# 50/50 [==============================] - 1s 21ms/step - loss: 4.3992e-06 - acc: 1.0000 - val_loss: 0.4780 - val_acc: 0.8000
# Epoch 47/100
# 50/50 [==============================] - 1s 21ms/step - loss: 3.9792e-06 - acc: 1.0000 - val_loss: 0.4733 - val_acc: 0.8000
# Epoch 48/100
# 50/50 [==============================] - 1s 22ms/step - loss: 3.9013e-06 - acc: 1.0000 - val_loss: 0.4648 - val_acc: 0.8000
# Epoch 49/100
# 50/50 [==============================] - 1s 23ms/step - loss: 3.3546e-06 - acc: 1.0000 - val_loss: 0.4624 - val_acc: 0.8000
# Epoch 50/100
# 50/50 [==============================] - 1s 22ms/step - loss: 3.4173e-06 - acc: 1.0000 - val_loss: 0.4530 - val_acc: 0.8000
# Epoch 51/100
# 50/50 [==============================] - 1s 22ms/step - loss: 2.9604e-06 - acc: 1.0000 - val_loss: 0.4628 - val_acc: 0.8000
# Epoch 52/100
# 50/50 [==============================] - 1s 21ms/step - loss: 2.8213e-06 - acc: 1.0000 - val_loss: 0.4538 - val_acc: 0.8000
# Epoch 53/100
# 50/50 [==============================] - 1s 22ms/step - loss: 2.6663e-06 - acc: 1.0000 - val_loss: 0.4592 - val_acc: 0.8000
# Epoch 54/100
# 50/50 [==============================] - 1s 22ms/step - loss: 2.5694e-06 - acc: 1.0000 - val_loss: 0.4621 - val_acc: 0.8000
# Epoch 55/100
# 50/50 [==============================] - 1s 21ms/step - loss: 2.3600e-06 - acc: 1.0000 - val_loss: 0.4589 - val_acc: 0.8000
# Epoch 56/100
# 50/50 [==============================] - 1s 21ms/step - loss: 2.3381e-06 - acc: 1.0000 - val_loss: 0.4565 - val_acc: 0.8000
# Epoch 57/100
# 50/50 [==============================] - 1s 21ms/step - loss: 2.0893e-06 - acc: 1.0000 - val_loss: 0.4455 - val_acc: 0.8667
# Epoch 58/100
# 50/50 [==============================] - 1s 21ms/step - loss: 1.9801e-06 - acc: 1.0000 - val_loss: 0.4700 - val_acc: 0.8000
# Epoch 59/100
# 50/50 [==============================] - 1s 21ms/step - loss: 1.8847e-06 - acc: 1.0000 - val_loss: 0.4669 - val_acc: 0.8000
# Epoch 60/100
# 50/50 [==============================] - 1s 21ms/step - loss: 1.7957e-06 - acc: 1.0000 - val_loss: 0.4550 - val_acc: 0.8000
# Epoch 61/100
# 50/50 [==============================] - 1s 22ms/step - loss: 1.6936e-06 - acc: 1.0000 - val_loss: 0.4478 - val_acc: 0.8000
# Epoch 62/100
# 50/50 [==============================] - 1s 22ms/step - loss: 1.6407e-06 - acc: 1.0000 - val_loss: 0.4477 - val_acc: 0.8000
# Epoch 63/100
# 50/50 [==============================] - 1s 21ms/step - loss: 1.4937e-06 - acc: 1.0000 - val_loss: 0.4421 - val_acc: 0.8000
# Epoch 64/100
# 50/50 [==============================] - 1s 22ms/step - loss: 1.5279e-06 - acc: 1.0000 - val_loss: 0.4483 - val_acc: 0.8000
# Epoch 65/100
# 50/50 [==============================] - 1s 21ms/step - loss: 1.3038e-06 - acc: 1.0000 - val_loss: 0.4493 - val_acc: 0.8000
# Epoch 66/100
# 50/50 [==============================] - 1s 21ms/step - loss: 1.2616e-06 - acc: 1.0000 - val_loss: 0.4415 - val_acc: 0.8000
# Epoch 67/100
# 50/50 [==============================] - 1s 22ms/step - loss: 1.2767e-06 - acc: 1.0000 - val_loss: 0.4504 - val_acc: 0.8000
# Epoch 68/100
# 50/50 [==============================] - 1s 21ms/step - loss: 1.1603e-06 - acc: 1.0000 - val_loss: 0.4354 - val_acc: 0.8000
# Epoch 69/100
# 50/50 [==============================] - 1s 21ms/step - loss: 1.1651e-06 - acc: 1.0000 - val_loss: 0.4444 - val_acc: 0.8000
# Epoch 70/100
# 50/50 [==============================] - 1s 22ms/step - loss: 1.0486e-06 - acc: 1.0000 - val_loss: 0.4427 - val_acc: 0.8000
# Epoch 71/100
# 50/50 [==============================] - 1s 21ms/step - loss: 1.0653e-06 - acc: 1.0000 - val_loss: 0.4387 - val_acc: 0.8000
# Epoch 72/100
# 50/50 [==============================] - 1s 22ms/step - loss: 9.1910e-07 - acc: 1.0000 - val_loss: 0.4347 - val_acc: 0.8000
# Epoch 73/100
# 50/50 [==============================] - 1s 21ms/step - loss: 9.8904e-07 - acc: 1.0000 - val_loss: 0.4277 - val_acc: 0.8000
# Epoch 74/100
# 50/50 [==============================] - 1s 22ms/step - loss: 8.9089e-07 - acc: 1.0000 - val_loss: 0.4319 - val_acc: 0.8000
# Epoch 75/100
# 50/50 [==============================] - 1s 21ms/step - loss: 8.3804e-07 - acc: 1.0000 - val_loss: 0.4307 - val_acc: 0.8000
# Epoch 76/100
# 50/50 [==============================] - 1s 21ms/step - loss: 8.2811e-07 - acc: 1.0000 - val_loss: 0.4307 - val_acc: 0.8000
# Epoch 77/100
# 50/50 [==============================] - 1s 22ms/step - loss: 7.8837e-07 - acc: 1.0000 - val_loss: 0.4390 - val_acc: 0.8000
# Epoch 78/100
# 50/50 [==============================] - 1s 22ms/step - loss: 7.5340e-07 - acc: 1.0000 - val_loss: 0.4313 - val_acc: 0.8000
# Epoch 79/100
# 50/50 [==============================] - 1s 20ms/step - loss: 7.4228e-07 - acc: 1.0000 - val_loss: 0.4261 - val_acc: 0.8000
# Epoch 80/100
# 50/50 [==============================] - 1s 21ms/step - loss: 7.1367e-07 - acc: 1.0000 - val_loss: 0.4175 - val_acc: 0.8000
# Epoch 81/100
# 50/50 [==============================] - 1s 22ms/step - loss: 6.4651e-07 - acc: 1.0000 - val_loss: 0.4274 - val_acc: 0.8000
# Epoch 82/100
# 50/50 [==============================] - 1s 22ms/step - loss: 6.0360e-07 - acc: 1.0000 - val_loss: 0.4278 - val_acc: 0.8000
# Epoch 83/100
# 50/50 [==============================] - 1s 22ms/step - loss: 6.6042e-07 - acc: 1.0000 - val_loss: 0.4227 - val_acc: 0.8000
# Epoch 84/100
# 50/50 [==============================] - 1s 21ms/step - loss: 5.8254e-07 - acc: 1.0000 - val_loss: 0.4185 - val_acc: 0.8000
# Epoch 85/100
# 50/50 [==============================] - 1s 22ms/step - loss: 5.6545e-07 - acc: 1.0000 - val_loss: 0.4197 - val_acc: 0.8000
# Epoch 86/100
# 50/50 [==============================] - 1s 23ms/step - loss: 5.6783e-07 - acc: 1.0000 - val_loss: 0.4153 - val_acc: 0.8000
# Epoch 87/100
# 50/50 [==============================] - 1s 21ms/step - loss: 5.2293e-07 - acc: 1.0000 - val_loss: 0.4213 - val_acc: 0.8000
# Epoch 88/100
# 50/50 [==============================] - 1s 21ms/step - loss: 4.9949e-07 - acc: 1.0000 - val_loss: 0.4236 - val_acc: 0.8000
# Epoch 89/100
# 50/50 [==============================] - 1s 21ms/step - loss: 5.4717e-07 - acc: 1.0000 - val_loss: 0.4191 - val_acc: 0.8000
# Epoch 90/100
# 50/50 [==============================] - 1s 22ms/step - loss: 4.6134e-07 - acc: 1.0000 - val_loss: 0.4145 - val_acc: 0.8000
# Epoch 91/100
# 50/50 [==============================] - 1s 22ms/step - loss: 4.4425e-07 - acc: 1.0000 - val_loss: 0.4138 - val_acc: 0.8000
# Epoch 92/100
# 50/50 [==============================] - 1s 22ms/step - loss: 4.5101e-07 - acc: 1.0000 - val_loss: 0.4106 - val_acc: 0.8000
# Epoch 93/100
# 50/50 [==============================] - 1s 21ms/step - loss: 4.2280e-07 - acc: 1.0000 - val_loss: 0.4035 - val_acc: 0.8000
# Epoch 94/100
# 50/50 [==============================] - 1s 21ms/step - loss: 4.3074e-07 - acc: 1.0000 - val_loss: 0.4122 - val_acc: 0.8000
# Epoch 95/100
# 50/50 [==============================] - 1s 21ms/step - loss: 3.9538e-07 - acc: 1.0000 - val_loss: 0.4100 - val_acc: 0.8000
# Epoch 96/100
# 50/50 [==============================] - 1s 23ms/step - loss: 3.6240e-07 - acc: 1.0000 - val_loss: 0.4074 - val_acc: 0.8000
# Epoch 97/100
# 50/50 [==============================] - 1s 22ms/step - loss: 4.0770e-07 - acc: 1.0000 - val_loss: 0.4062 - val_acc: 0.8000
# Epoch 98/100
# 50/50 [==============================] - 1s 20ms/step - loss: 3.6319e-07 - acc: 1.0000 - val_loss: 0.4020 - val_acc: 0.8000
# Epoch 99/100
# 50/50 [==============================] - 1s 23ms/step - loss: 3.4531e-07 - acc: 1.0000 - val_loss: 0.4021 - val_acc: 0.8000
# Epoch 100/100
# 50/50 [==============================] - 1s 23ms/step - loss: 3.5008e-07 - acc: 1.0000 - val_loss: 0.4070 - val_acc: 0.8000

# %% [markdown]
# (7) 학습모델 모니터링하기

# %%
# Multi&Binary5. 학습과정 살펴보기
#%matplotlib inline
#import matplotlib.pyplot as plt

#fig, loss_ax = plt.subplots()

#acc_ax = loss_ax.twinx()

#loss_ax.plot(hist.history['loss'], 'y', label='train loss')
#loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')
#loss_ax.set_ylim([0.0, 0.5])

#acc_ax.plot(hist.history['acc'], 'b', label='train acc')
#acc_ax.plot(hist.history['val_acc'], 'g', label='val acc')
#acc_ax.set_ylim([0.8, 1.0])

#loss_ax.set_xlabel('epoch')
#loss_ax.set_ylabel('loss')
#acc_ax.set_ylabel('accuray')

#loss_ax.legend(loc='upper left')
#acc_ax.legend(loc='lower left')

#plt.show()

fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'y', label='train loss')
loss_ax.plot(history.history['val_loss'], 'r', label='val loss')

acc_ax.plot(history.history['acc'], 'b', label='train acc')
acc_ax.plot(history.history['val_acc'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %% [markdown]
# (8) 검증모델 테스트하기

# %%
print("-- Test --")
output = model.predict_generator(test_generator, steps=5)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
print(test_generator.class_indices)
print(output)
# Out:
# -- Test --
# {'TG': 0, 'WT': 1}
# [[0.799 0.201]
#  [0.000 1.000]
#  [0.155 0.845]
#  [1.000 0.000]
#  [0.000 1.000]
#  [0.996 0.004]
#  [0.000 1.000]
#  [0.000 1.000]
#  [0.020 0.980]
#  [1.000 0.000]
#  [0.012 0.988]
#  [0.000 1.000]
#  [0.002 0.998]
#  [0.000 1.000]
#  [1.000 0.000]]

# %% [markdown]
# (9) 모델 평가하기

# %%
#Multinary, Binary 6. 모델 평가하기
#loss_and_metrics = model.evaluate(x_test, y_test, batch_size=32)
#print('## evaluation loss and_metrics ##')
#print(loss_and_metrics)

print("-- Evaluate --")
scores = model.evaluate_generator(test_generator, steps=5)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))
# Out:
# -- Evaluate --
# acc: 73.33%

# %% [markdown]
# (10) 모델 구조 및 학습된 모델 가중치 저장하기

# %%
model.save('ASAP_weight.h5')
with open('model_architecture.json', 'w') as f:
    f.write(model.to_json())

# %% [markdown]
# (11) 모델 사용하기

# %%
#Mulyinary 7. 모델 사용하기, 틀린것 만 보이기
#yhat_test = model.predict(x_test, batch_size=32)

#%matplotlib inline
#import matplotlib.pyplot as plt

#plt_row = 5
#plt_col = 5

#plt.rcParams["figure.figsize"] = (10,10)

#f, axarr = plt.subplots(plt_row, plt_col)

#cnt = 0
#i = 0

#while cnt < (plt_row*plt_col):
    
#    if np.argmax(y_test[i]) == np.argmax(yhat_test[i]):
#        i += 1
#        continue
    
 #   sub_plt = axarr[cnt//plt_row, cnt%plt_col]
 #   sub_plt.axis('off')
 #   sub_plt.imshow(x_test[i].reshape(width, height))
 #   sub_plt_title = 'R: ' + str(np.argmax(y_test[i])) + ' P: ' + str(np.argmax(yhat_test[i]))
 #   sub_plt.set_title(sub_plt_title)

  #  i += 1    
  #  cnt += 1

#plt.show()

#Binary 7. 모델 사용하기, 홀짝
#yhat_test = model.predict(x_test, batch_size=32)

#%matplotlib inline
#import matplotlib.pyplot as plt

#plt_row = 5
#plt_col = 5

#plt.rcParams["figure.figsize"] = (10,10)

#f, axarr = plt.subplots(plt_row, plt_col)

#for i in range(plt_row*plt_col):
#    sub_plt = axarr[int(i/plt_row), int(i%plt_col)]
#    sub_plt.axis('off')
#    sub_plt.imshow(x_test[i].reshape(width, height))
    
#    sub_plt_title = 'R: '
    
#    if y_test[i] :
#        sub_plt_title += 'odd '
#    else:
#        sub_plt_title += 'even '

#    sub_plt_title += 'P: '
    
#    if yhat_test[i] >= 0.5 :
#        sub_plt_title += 'odd '
#    else:
#        sub_plt_title += 'even '        
    
#    sub_plt.set_title(sub_plt_title)

#plt.show()

# %% [markdown]
# # Execution Phase

# %% [markdown]
# (1) 사용할 패키지 불러오기

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# %matplotlib inline
# import matplotlib.image as mpimg
# from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# (2) 예측할 데이터 생성하기

# %%
# new_datagen = ImageDataGenerator(rescale = 1./255)

# new_generator = new_datagen.flow_from_directory('rawData/new',
#                                                  target_size = (32,32),
#                                                  batch_size = 3,
#                                                  class_mode = 'categorical')

# %% [markdown]
# (3) 저장된 학습 모델 및 가중치 불러오기

# %%
# from keras.models import model_from_json

# Model reconstruction from JSON file
# with open('model_architecture.json', 'r') as f:
#    model = model_from_json(f.read())

# Load weights into the new model
# model.load_weights('ASAP_weight.h5')

# %% [markdown]
# (4) 예측하기

# %%
# print("-- Predict --")
# output = model.predict_generator(new_generator, steps=1)
# np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
# print(new_generator.class_indices)
# print(output) # It doesn't matter with the result which folder you put the new data.
